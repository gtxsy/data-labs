# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

vehicles = pd.read_csv('./data/vehicles.csv')

# Multiple Line Plots
vehicles.sort_values(by=["CO2 Emission Grams/Mile", "City MPG", "Highway MPG"], inplace=True)
vehicles.plot(x="CO2 Emission Grams/Mile", y=["City MPG", "Highway MPG"])

# %%
# Multiple Side-by-Side Bar Plots
vehicles_mean = vehicles[["Highway MPG", "City MPG", "Drivetrain"]].groupby(["Drivetrain"]).agg("mean")
vehicles_mean.plot.bar()

# %%
# Side-by-Side Horizontal Bar Plots
vehicles_mean.plot.barh()

# %%
# Scatter Matrices
pd.plotting.scatter_matrix(vehicles)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c1fb588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c788a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c7c8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c7f8630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c829be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8691d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c898780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8c8d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8c8da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c9378d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c96ee80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c9a8470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c9dda20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ca0ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ca4b5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ca7cb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cabb160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11caea710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11cb1acc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cb5b2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cb8c860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cbbde10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cbfb400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cc2b9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cc5ff60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cc9c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ccceb00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11cd0b0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cd3f6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cd6fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cdae240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cde07f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ce11da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ce4d390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ce80940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ceb1ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11ceef4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cf22a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cf61080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cf90630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cfc2be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d0011d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d030780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d062d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d0a1320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d0d08d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d106e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d141470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d174a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d1a5fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d1e25c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d3a0b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d3e1160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d410710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d442cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d4822b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d4b2860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d4e2e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d521400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d5509b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d585f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d5c3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d5f4b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d6310f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d6626a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d694c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d6d4240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d7037f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d737da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d773390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d7a4940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d7d6ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d8154e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d847a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d885080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d8b5630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d8e8be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d9241d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d956780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d98ad30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d9c8320>]],
#       dtype=object)
